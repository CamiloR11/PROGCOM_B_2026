# %% [markdown]
# <a href="https://colab.research.google.com/github/CamiloR11/PROGCOM_B_2026/blob/main/Diccionarios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #DICCIONARIOS
# 1. Ttipo de dato
# 2. **NO TIENEN INDEX**. Tiene clave: valor
# 3. Las claves **SIEMPRE SON CARACTERES**
# 4. Lo svalores puedes ser cualquier otro tipo de dato
#
# Sintaxis
# variable={"clase1" : valor, "clase2": valor}

# %%
galleta=["dinosaurio","flores","carro"]
precio=[5000,6000,7000]
cant=[5,5,6]

# %%
def menu():
  for galletas in range(3):
    print(f"galleta={galleta[galletas]}, precio={precio[galletas]}, cantidad={cant[galletas]}")

# %%
menu()
# Out:
# galleta=dinosaurio, precio=5000, cantidad=5
# galleta=flores, precio=6000, cantidad=5
# galleta=carro, precio=7000, cantidad=6

# %%
para_vender={"galleta":["dinosaurio","flores","carro"],
             "precio":[5000,6000,7000],
             "cant":[5,5,6]}

# %%
type(para_vender)
# Out:
# dict

# %%
para_vender["galleta"]
# Out:
# ['dinosaurio', 'flores', 'carro']

# %%
para_vender["precio"][1:3]
# Out:
# [6000, 7000]

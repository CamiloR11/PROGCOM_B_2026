# %% [markdown]
# <a href="https://colab.research.google.com/github/CamiloR11/PROGCOM_B_2026/blob/main/BAILE_CODIGO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def mover(cadera,veces):
  for i in range(veces):
  for j in range(veces):
    print("muevo cadera derecha")
  for k in range (cadera):
# Out:
#   File "/tmp/ipykernel_1639/486474324.py", line 3
#     for j in range(veces):
#     ^
# IndentationError: expected an indented block after 'for' statement on line 2

# %%
for i in range (4):
  print("muevo cadera derecha")
  print("muevo cadera derecha")
  print("muevo cadera izquierda")
  print("muevo cadera izquierda")
for i in range (4):
  print("muevo cadera derecha")
  print("muevo cadera izquierda")
# Out:
# muevo cadera derecha
# muevo cadera derecha
# muevo cadera izquierda
# muevo cadera izquierda
# muevo cadera derecha
# muevo cadera derecha
# muevo cadera izquierda
# muevo cadera izquierda
# muevo cadera derecha
# muevo cadera derecha
# muevo cadera izquierda
# muevo cadera izquierda
# muevo cadera derecha
# muevo cadera derecha
# muevo cadera izquierda
# muevo cadera izquierda
# muevo cadera derecha
# muevo cadera izquierda
# muevo cadera derecha
# muevo cadera izquierda
# muevo cadera derecha
# muevo cadera izquierda
# muevo cadera derecha
# muevo cadera izquierda

# %%
mover(2,4)
mover(1,4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1639/3644027651.py in <cell line: 0>()
# ----> 1 mover(2,4)
#       2 mover(1,4)
#
# NameError: name 'mover' is not defined

# %% [markdown]
# <a href="https://colab.research.google.com/github/CamiloR11/PROGCOM_B_2026/blob/main/EJERCICIOS_CLASE_CAMILO_RODRIGUEZ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Ingrese un número: "))

for i in range(1, 11):
 print(f"{num} x {i} = {num*i}")
# Out:
# Ingrese un número: 5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
n = int(input("Ingrese un número: "))
suma = 0

for i in range(1, n+1):
 suma = suma + i

print("La suma es:", suma)
# Out:
# Ingrese un número: 5
# La suma es: 15

# %%
n = int(input("Ingrese un número: "))

if n < 0:
 print("No existen factoriales negativos")
else:
 factorial = 1
for i in range(1, n+1):
 factorial = factorial * i
print("El factorial es:", factorial)
# Out:
# Ingrese un número: 5
# El factorial es: 120

# %%
n = int(input("Cuántos números de Fibonacci desea: "))

a = 0
b = 1

for i in range(n):
 print(a)
c = a + b
a = b
b = c
# Out:
# Cuántos números de Fibonacci desea: 5
# 0
# 0
# 0
# 0
# 0

# %%
color_secreto = input("Defina el color secreto: ")
intentos = 10

for i in range(1, intentos+1):
intento=input("Adivine el color: ")

if intento == color_secreto:
  print("Correcto!")
else:
 print("Incorrecto")

if i == 10:
 print("Se acabaron los intentos")
# Out:
# Defina el color secreto: negro
# Adivine el color: Negro
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_431/3450750623.py in <cell line: 0>()
#       3
#       4 for i in range(1, intentos+1):
# ----> 5  intento = input("Adivine el color: ")
#       6
#       7 if intento == color_secreto:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
for i in range(1, 101):
 if i % 2 == 0:
  print(i)

# %%
num = int(input("Ingrese un número: "))
suma = 0

for i in str(num):
 suma = suma + int(i)

print("La suma de los dígitos es:", suma)
# Out:
# Ingrese un número: 524
# La suma de los dígitos es: 11

# %%
num = int(input("Ingrese un número: "))
contador = 0

for i in range(1, num+1):
 if num % i == 0:
  contador = contador + 1

if contador == 2:
 print("Es primo")
else:
 print("No es primo")
# Out:
# Ingrese un número: 10
# No es primo

# %%
n = int(input("Ingrese la altura del triángulo: "))

for i in range(1, n+1):
  print("*" * i)
# Out:
# Ingrese la altura del triángulo: 20
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********
# ***********
# ************
# *************
# **************
# ***************
# ****************
# *****************
# ******************
# *******************
# ********************
